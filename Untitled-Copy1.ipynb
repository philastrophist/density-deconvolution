# %%
# %matplotlib inline

# %%
from plot_data_flux_mass import *
# Out:
# /home/ppzscr/anaconda3/envs/star-forming/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Retrieving previous parameters from /home/ppzscr/star-forming/data/noise-16comps_seed0_tol1e-08.h5
# bad redshifts: 17
# outlier line fluxes: 244
# setting 72 D4000_ERR to 2 * 99.0%
# saving to models/noisy-all-uncut-R-mass
# NOT doing radio flux noise subtraction

# %%
Plotter(['logM', 'R']).plot_epoch(800)

# %%
means = torch.median(fitting2data(train_data.X), axis=0, keepdims=True)[0]
errs = torch.median(error_transform.fitting2data(fitting2data(train_data.X), train_data.noise_covars), axis=0, keepdims=True)[0]

# %%
means = torch.tensor([[10.4, 16.5]])
errs = torch.tensor([[0.1, 0.1]])

# %%
Plotter(['logM', 'R']).plot_epoch_q(means, errs, 800);

# %%
plotter = Plotter(['logM', 'R'])
plotter.update()
i, w, n = 850, 1, 864

df = plotter.df.iloc[i:n]
plt.plot(df.epoch, df.train.rolling(w).mean())
Plotter(['logM', 'R']).plot_epoch(n)
Plotter(['logM', 'R']).plot_epoch_q(means, errs, n);

# %%
df.train.argmax()
# Out:
# 135

# %%
# %matplotlib inline

# %%
plotter = Plotter(['T(R)', 'T(logM)'])
plotter.plot_epoch(0)
fig = plotter.c.plotter.fig_data[0]

bar = tqdm(range(750, 864))
def func(i):
    bar.update()
    return plotter.plot_epoch(i)
anim1 = animation.FuncAnimation(fig, func, interval=400, frames=range(750, 864), repeat=False)
from IPython import display
video = anim1.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# /home/ppzscr/PycharmProjects/density-deconvolution/fit_data_flux_mass_noisy.py:685: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   c.axins_losses.set_xlim(max([0, max(record_df['epoch']) - 20]), max(record_df['epoch']))
# /home/ppzscr/PycharmProjects/density-deconvolution/fit_data_flux_mass_noisy.py:802: UserWarning: Attempting to set identical bottom == top == -6257946.58203125 results in singular transformations; automatically expanding.
#   ax.set_ylim(bot,top)
#
#   0%|          | 0/114 [00:00<?, ?it/s]INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 216x216 -pix_fmt rgba -r 2.5 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /tmp/tmp9zmlww2r/temp.m4v
#
# ...
#   2%|▏         | 2/114 [00:20<19:30, 10.45s/it]
#
# ...

# %%
plotter = Plotter(['T(R)', 'T(logM)'])
plotter.plot_epoch_q(means, errs, 0)
fig = plotter.qc.plotter.fig_data[0]

bar = tqdm(range(750, 864))
def func(i):
    bar.update()
    return plotter.plot_epoch_q(means, errs, i)
anim1 = animation.FuncAnimation(fig, func, interval=400, frames=range(750, 864), repeat=False)
from IPython import display
video = anim1.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 216x216 -pix_fmt rgba -r 2.5 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /tmp/tmp3nghcplq/temp.m4v
# 115it [01:34,  1.22it/s][00:07<01:17,  1.33it/s]
# 115it [01:30,  1.25it/s]
# <video width="216" height="216" controls autoplay>
#   <source type="video/mp4" src="...
