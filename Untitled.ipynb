# %%
# %matplotlib inline

# %%
from plot_data_flux_mass import *
# Out:
# /home/ppzscr/anaconda3/envs/star-forming/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Retrieving previous parameters from /home/ppzscr/star-forming/data/noise-16comps_seed0_tol1e-08.h5
# bad redshifts: 17
# outlier line fluxes: 244
# setting 72 D4000_ERR to 2 * 99.0%
# validation=100, training=900 (10.00%)
# saving to models/noisy-all-uncut-d4000-mass
# NOT doing radio flux noise subtraction

# %%
Plotter(['logM', 'R']).plot_epoch(20)

# %%
plotter = Plotter(['T(logM)', 'T(R)'])
i = 100
plotter.plot_epoch(i)
plotter.plot_epoch_q(means, errs, i);

# %%
plotter = Plotter(['T(logM)', 'T(R)'])
plotter.update(500)
plt.scatter(*plotter.svi.sample_prior(100_000).detach().numpy().T, s=1);
plotter = Plotter(['T(logM)', 'T(R)'])
plotter.update()
plt.scatter(*plotter.svi.sample_prior(100_000).detach().numpy().T, s=1);
plt.scatter(*X_train.T, s=1);

# %%
means = torch.median(fitting2data(train_data.X), axis=0, keepdims=True)[0]
errs = torch.median(error_transform.fitting2data(fitting2data(train_data.X), train_data.noise_covars), axis=0, keepdims=True)[0]

# %%
means = torch.tensor([[10.4, 16.5]])
errs = torch.tensor([[0.01, 0.01]])

# %%
Plotter(['logM', 'R']).plot_epoch_q(means, errs);

# %%
plotter = Plotter(['logM', 'R'])
plotter.update()
i, w = 10, 10
df = plotter.df.iloc[i:]
plt.plot(df.epoch, df.train.rolling(w).mean())
plt.twinx().plot(df.epoch, df.val.rolling(w).mean(), 'r-')

# %%
# %matplotlib inline

# %%
plotter = Plotter(['T(R)', 'T(logM)'])
plotter.plot_epoch(0)
fig = plotter.c.plotter.fig_data[0]
n = 250
bar = tqdm(range(n))
def func(i):
    bar.update()
    return plotter.plot_epoch(i)
anim1 = animation.FuncAnimation(fig, func, interval=100, frames=n, repeat=False)
from IPython import display
video = anim1.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# /home/ppzscr/PycharmProjects/density-deconvolution/fit_data_flux_mass_noisy.py:685: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   c.axins_losses.set_xlim(max([0, max(record_df['epoch']) - 20]), max(record_df['epoch']))
# /home/ppzscr/PycharmProjects/density-deconvolution/fit_data_flux_mass_noisy.py:777: UserWarning: Attempting to set identical bottom == top == -3871858.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(bot,top)
# /home/ppzscr/PycharmProjects/density-deconvolution/fit_data_flux_mass_noisy.py:777: UserWarning: Attempting to set identical bottom == top == -179537.125 results in singular transformations; automatically expanding.
#   ax.set_ylim(bot,top)
#   0%|          | 0/250 [00:00<?, ?it/s]INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# ...

# %%
plotter = Plotter(['T(R)', 'T(logM)'])
plotter.plot_epoch_q(means, errs, 0)
fig = plotter.qc.plotter.fig_data[0]
n = 250
bar = tqdm(range(n))
def func(i):
    bar.update()
    return plotter.plot_epoch_q(means, errs, i)
anim1 = animation.FuncAnimation(fig, func, interval=100, frames=range(500, 750, 50), repeat=False)
from IPython import display
video = anim1.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 216x216 -pix_fmt rgba -r 10.0 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /tmp/tmphaivwg1v/temp.m4v
#
# ...
#   2%|▏         | 6/250 [00:05<04:15,  1.05s/it]
# <video width="216" height="216" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
