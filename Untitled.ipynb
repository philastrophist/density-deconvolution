# %%
# %matplotlib inline

# %%
from plot_data_flux_mass import *
# Out:
# /home/ppzscr/anaconda3/envs/star-forming/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Retrieving previous parameters from /home/ppzscr/star-forming/data/noise-16comps_seed0_tol1e-08.h5
# bad redshifts: 17
# outlier line fluxes: 244
# setting 72 D4000_ERR to 2 * 99.0%
# saving to models/noisy-all-uncut-all-expect-f150
# NOT doing radio flux noise subtraction

# %%
names = ['z', 'logM', 'ha', 'hb', 'nii', 'oiii', 'D4000', 'R']

# %%
means = torch.tensor([[0.05, 9.5, 400, 90, 150, 130, 2, 15]])
errs = torch.tensor([[0.005, 0.1, 10, 10, 10, 10, 0.1, 0.1]])

# %%
plotter = Plotter(names)
plotter.update()
i, w, n = 300, 15, None

df = plotter.df.iloc[i:n]
plt.plot(df.epoch, df.train, 'k-', alpha=0.1)
plt.plot(df.epoch, df.train.rolling(w).mean())
Plotter(names).plot_epoch(n)
# Plotter(names).plot_epoch_q(means, errs, n);

# %%
from astropy.cosmology import Planck18

# %%
distmod = Planck18.distmod(overlapped['redshift']).value

# %%
mag = 22.5 - 2.5 * np.log10(overlapped['cModelFlux_r']) - distmod

# %%
magerr = np.abs(2.5 * 0.434 / np.sqrt(overlapped['cModelFluxIvar_r']) / overlapped['cModelFlux_r'])

# %%
overlapped['cModel']
